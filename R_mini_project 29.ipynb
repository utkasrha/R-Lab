# %% [markdown]
# <a href="https://colab.research.google.com/github/utkasrha/R-Lab/blob/main/R_mini_project%2029.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
id <- "1miMpkK9vRhsTaKAyCao0qoZ1fA6ZO_om" # google file ID
data <- read.csv(sprintf("https://docs.google.com/uc?id=%s&export=download", id), na.strings=c("","NA"))
data
# Out:
#       No    year month day hour pm2.5 DEWP TEMP PRES cbwd Iws    Is Ir
# 1      1    2010 1     1    0    NA   -21  -11  1021 NW    1.79  0  0
# 2      2    2010 1     1    1    NA   -21  -12  1020 NW    4.92  0  0
# 3      3    2010 1     1    2    NA   -21  -11  1019 NW    6.71  0  0
# 4      4    2010 1     1    3    NA   -21  -14  1019 NW    9.84  0  0
# 5      5    2010 1     1    4    NA   -20  -12  1018 NW   12.97  0  0
# 6      6    2010 1     1    5    NA   -19  -10  1017 NW   16.10  0  0
# 7      7    2010 1     1    6    NA   -19   -9  1017 NW   19.23  0  0
# 8      8    2010 1     1    7    NA   -19   -9  1017 NW   21.02  0  0
# 9      9    2010 1     1    8    NA   -19   -9  1017 NW   24.15  0  0
# 10    10    2010 1     1    9    NA   -20   -8  1017 NW   27.28  0  0
# 11    11    2010 1     1   10    NA   -19   -7  1017 NW   31.30  0  0
# 12    12    2010 1     1   11    NA   -18   -5  1017 NW   34.43  0  0
# 13    13    2010 1     1   12    NA   -19   -5  1015 NW   37.56  0  0
# 14    14    2010 1     1   13    NA   -18   -3  1015 NW   40.69  0  0
# 15    15    2010 1     1   14    NA   -18   -2  1014 NW   43.82  0  0
# 16    16    2010 1     1   15    NA   -18   -1  1014 cv    0.89  0  0
# 17    17    2010 1     1   16    NA   -19   -2  1015 NW    1.79  0  0
# 18    18    2010 1     1   17    NA   -18   -3  1015 NW    2.68  0  0
# 19    19    2010 1     1   18    NA   -18   -5  1016 NE    1.79  0  0
# 20    20    2010 1     1   19    NA   -17   -4  1017 NW    1.79  0  0
# 21    21    2010 1     1   20    NA   -17   -5  1017 cv    0.89  0  0
# 22    22    2010 1     1   21    NA   -17   -5  1018 NW    1.79  0  0
# 23    23    2010 1     1   22    NA   -17   -5  1018 NW    2.68  0  0
# 24    24    2010 1     1   23    NA   -17   -5  1020 cv    0.89  0  0
# 25    25    2010 1     2    0   129   -16   -4  1020 SE    1.79  0  0
# 26    26    2010 1     2    1   148   -15   -4  1020 SE    2.68  0  0
# 27    27    2010 1     2    2   159   -11   -5  1021 SE    3.57  0  0
# 28    28    2010 1     2    3   181    -7   -5  1022 SE    5.36  1  0
# 29    29    2010 1     2    4   138    -7   -5  1022 SE    6.25  2  0
# 30    30    2010 1     2    5   109    -7   -6  1022 SE    7.14  3  0
# ⋮     ⋮     ⋮    ⋮     ⋮   ⋮    ⋮     ⋮    ⋮    ⋮    ⋮    ⋮      ⋮  ⋮
# 43795 43795 2014 12    30  18   79    -13   2   1020 NE     3.58 0  0
# 43796 43796 2014 12    30  19   35     -8   6   1021 NW     5.81 0  0
# 43797 43797 2014 12    30  20   26    -11   5   1022 NW    12.96 0  0
# 43798 43798 2014 12    30  21   20    -12   4   1023 NW    21.90 0  0
# 43799 43799 2014 12    30  22    8    -21   2   1025 NW    31.73 0  0
# 43800 43800 2014 12    30  23   16    -22   0   1026 NW    38.88 0  0
# 43801 43801 2014 12    31   0   10    -19  -1   1027 NW    51.84 0  0
# 43802 43802 2014 12    31   1   11    -18  -1   1028 NW    61.67 0  0
# 43803 43803 2014 12    31   2   20    -17  -1   1028 NW    70.61 0  0
# 43804 43804 2014 12    31   3    9    -17  -1   1029 NW    81.79 0  0
# 43805 43805 2014 12    31   4    8    -19  -2   1030 NW    94.75 0  0
# 43806 43806 2014 12    31   5    9    -21  -3   1030 NW   109.95 0  0
# 43807 43807 2014 12    31   6    8    -23  -4   1032 NW   130.07 0  0
# 43808 43808 2014 12    31   7    8    -22  -5   1034 NW   143.03 0  0
# 43809 43809 2014 12    31   8    8    -22  -5   1034 NW   150.18 0  0
# 43810 43810 2014 12    31   9    8    -22  -3   1034 NW   155.99 0  0
# 43811 43811 2014 12    31  10    7    -22  -2   1034 NW   163.14 0  0
# 43812 43812 2014 12    31  11   12    -22  -2   1034 NW   170.29 0  0
# 43813 43813 2014 12    31  12   17    -22   0   1033 NW   177.44 0  0
# 43814 43814 2014 12    31  13   11    -27   0   1032 NW   186.38 0  0
# 43815 43815 2014 12    31  14    9    -27   1   1032 NW   196.21 0  0
# 43816 43816 2014 12    31  15   11    -26   1   1032 NW   205.15 0  0
# 43817 43817 2014 12    31  16    8    -23   0   1032 NW   214.09 0  0
# 43818 43818 2014 12    31  17    9    -22  -1   1033 NW   221.24 0  0
# 43819 43819 2014 12    31  18   10    -22  -2   1033 NW   226.16 0  0
# 43820 43820 2014 12    31  19    8    -23  -2   1034 NW   231.97 0  0
# 43821 43821 2014 12    31  20   10    -22  -3   1034 NW   237.78 0  0
# 43822 43822 2014 12    31  21   10    -22  -3   1034 NW   242.70 0  0
# 43823 43823 2014 12    31  22    8    -22  -4   1034 NW   246.72 0  0
# 43824 43824 2014 12    31  23   12    -21  -3   1034 NW   249.85 0  0

# %%
# a. summarize the entire data using apropriate R Command.
library(dplyr)

summary(data)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#        No             year          month             day
#  Min.   :    1   Min.   :2010   Min.   : 1.000   Min.   : 1.00
#  1st Qu.:10957   1st Qu.:2011   1st Qu.: 4.000   1st Qu.: 8.00
#  Median :21912   Median :2012   Median : 7.000   Median :16.00
#  Mean   :21912   Mean   :2012   Mean   : 6.524   Mean   :15.73
#  3rd Qu.:32868   3rd Qu.:2013   3rd Qu.:10.000   3rd Qu.:23.00
#  Max.   :43824   Max.   :2014   Max.   :12.000   Max.   :31.00
#
#       hour           pm2.5             DEWP              TEMP
#  Min.   : 0.00   Min.   :  0.00   Min.   :-40.000   Min.   :-19.00
#  1st Qu.: 5.75   1st Qu.: 29.00   1st Qu.:-10.000   1st Qu.:  2.00
#  Median :11.50   Median : 72.00   Median :  2.000   Median : 14.00
#  Mean   :11.50   Mean   : 98.61   Mean   :  1.817   Mean   : 12.45
#  3rd Qu.:17.25   3rd Qu.:137.00   3rd Qu.: 15.000   3rd Qu.: 23.00
#  Max.   :23.00   Max.   :994.00   Max.   : 28.000   Max.   : 42.00
#                  NA's   :2067
#       PRES          cbwd                Iws               Is
#  Min.   : 991   Length:43824       Min.   :  0.45   Min.   : 0.00000
#  1st Qu.:1008   Class :character   1st Qu.:  1.79   1st Qu.: 0.00000
#  Median :1016   Mode  :character   Median :  5.37   Median : 0.00000
#  Mean   :1016                      Mean   : 23.89   Mean   : 0.05273
#  3rd Qu.:1025                      3rd Qu.: 21.91   3rd Qu.: 0.00000
#  Max.   :1046                      Max.   :585.60   Max.   :27.00000
#
#        Ir
#  Min.   : 0.0000
#  1st Qu.: 0.0000
#  Median : 0.0000
#  Mean   : 0.1949
#  3rd Qu.: 0.0000
#  Max.   :36.0000

# %%
# b. show class of variable holding data
class(data)
# Out:
# [1] "data.frame"

# %%
# d. select any 2 atributes that are continuous valued and create a subset of original data with only those columns. 
# (e.g. sample_data(col1,col2, col3) is stored in variable my_data where as variable data_slice has only col2 and col3 and no other columns. Num of rows in both must be same.)


data_slice <- data %>% select(month:Iws)
summary(data_slice)
# Out:
#      month             day             hour           pm2.5
#  Min.   : 1.000   Min.   : 1.00   Min.   : 0.00   Min.   :  0.00
#  1st Qu.: 4.000   1st Qu.: 8.00   1st Qu.: 5.75   1st Qu.: 29.00
#  Median : 7.000   Median :16.00   Median :11.50   Median : 72.00
#  Mean   : 6.524   Mean   :15.73   Mean   :11.50   Mean   : 98.61
#  3rd Qu.:10.000   3rd Qu.:23.00   3rd Qu.:17.25   3rd Qu.:137.00
#  Max.   :12.000   Max.   :31.00   Max.   :23.00   Max.   :994.00
#                                                   NA's   :2067
#       DEWP              TEMP             PRES          cbwd
#  Min.   :-40.000   Min.   :-19.00   Min.   : 991   Length:43824
#  1st Qu.:-10.000   1st Qu.:  2.00   1st Qu.:1008   Class :character
#  Median :  2.000   Median : 14.00   Median :1016   Mode  :character
#  Mean   :  1.817   Mean   : 12.45   Mean   :1016
#  3rd Qu.: 15.000   3rd Qu.: 23.00   3rd Qu.:1025
#  Max.   : 28.000   Max.   : 42.00   Max.   :1046
#
#       Iws
#  Min.   :  0.45
#  1st Qu.:  1.79
#  Median :  5.37
#  Mean   : 23.89
#  3rd Qu.: 21.91
#  Max.   :585.60

# %%
# e. Write R function to sample tuples starting at index N to N+m from any data set provided.
bb <- data['TEMP']
sample(bb[1:10,])
# Out:
#  [1]  -9 -11 -12  -9 -11  -8 -10  -9 -14 -12

# %%
# a. find out how many values are missing in each of the columns of your data set.
tar <- data$month
sapply(data, function(tar) sum(is.na(tar)))
# Out:
#    No  year month   day  hour pm2.5  DEWP  TEMP  PRES  cbwd   Iws    Is    Ir
#     0     0     0     0     0  2067     0     0     0     0     0     0     0

# %%
# b. select colum with more than 10% values missing for deletation. Create new copy of dataset
# that has one less column call it sample_data_1less.

## Remove columns with more than 10% NA
dataless1 <-data[, which(colMeans(!is.na(data)) > 0.1)]

# %%
# c. Find 5 point summary of all remaining columns with numric attributes
summary(dataless1)
# Out:
#        No             year          month             day
#  Min.   :    1   Min.   :2010   Min.   : 1.000   Min.   : 1.00
#  1st Qu.:10957   1st Qu.:2011   1st Qu.: 4.000   1st Qu.: 8.00
#  Median :21912   Median :2012   Median : 7.000   Median :16.00
#  Mean   :21912   Mean   :2012   Mean   : 6.524   Mean   :15.73
#  3rd Qu.:32868   3rd Qu.:2013   3rd Qu.:10.000   3rd Qu.:23.00
#  Max.   :43824   Max.   :2014   Max.   :12.000   Max.   :31.00
#
#       hour           pm2.5             DEWP              TEMP
#  Min.   : 0.00   Min.   :  0.00   Min.   :-40.000   Min.   :-19.00
#  1st Qu.: 5.75   1st Qu.: 29.00   1st Qu.:-10.000   1st Qu.:  2.00
#  Median :11.50   Median : 72.00   Median :  2.000   Median : 14.00
#  Mean   :11.50   Mean   : 98.61   Mean   :  1.817   Mean   : 12.45
#  3rd Qu.:17.25   3rd Qu.:137.00   3rd Qu.: 15.000   3rd Qu.: 23.00
#  Max.   :23.00   Max.   :994.00   Max.   : 28.000   Max.   : 42.00
#                  NA's   :2067
#       PRES          cbwd                Iws               Is
#  Min.   : 991   Length:43824       Min.   :  0.45   Min.   : 0.00000
#  1st Qu.:1008   Class :character   1st Qu.:  1.79   1st Qu.: 0.00000
#  Median :1016   Mode  :character   Median :  5.37   Median : 0.00000
#  Mean   :1016                      Mean   : 23.89   Mean   : 0.05273
#  3rd Qu.:1025                      3rd Qu.: 21.91   3rd Qu.: 0.00000
#  Max.   :1046                      Max.   :585.60   Max.   :27.00000
#
#        Ir
#  Min.   : 0.0000
#  1st Qu.: 0.0000
#  Median : 0.0000
#  Mean   : 0.1949
#  3rd Qu.: 0.0000
#  Max.   :36.0000

# %%
# d. For attribute having maximum spread delete all tuples that have value less than the mean of the
# attribute selected. Count the number of tuples reamining in the sampled dataset.

m <- mean(data$TEMP, na.rm = FALSE)
m

df2 <- subset(data, data$TEMP< m)
summary(df2$TEMP)
print('Rows before row deletion: ')
nrow(data)
print('Rows before row deletion: ')
nrow(df2)
# Out:
# [1] 12.44852
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  -19.00   -3.00    1.00    1.28    7.00   12.00
# [1] "Rows before row deletion: "
# [1] 43824
# [1] "Rows before row deletion: "
# [1] 20836

# %%
# a. print the 5 point statistical summary for any 2 numeric attributes from your data set
fivenum(data$TEMP) 
fivenum(data$pm2.5)
# Out:
# [1] -19   2  14  23  42
# [1]   0  29  72 137 994

# %%
# b. select 2 atributes have closest mean value and draw a scatter plot with proper x and labelsloi
# ntt and title (for plotting you must use R library functions or gnuplot and not matplotlib )
means<- colMeans(data[sapply(data, is.numeric)] )
means

library(ggplot2)

DEWP<-data$DEWP
TEMP<-data$TEMP
plot(DEWP , TEMP , main = "Scatterplot" , xlab = "DEWP" , ylab = "TEMP" , las = 1 , xlim = c(0,50) , col = 4 )
# Out:
#           No         year        month          day         hour        pm2.5
# 2.191250e+04 2.012000e+03 6.523549e+00 1.572782e+01 1.150000e+01           NA
#         DEWP         TEMP         PRES          Iws           Is           Ir
# 1.817246e+00 1.244852e+01 1.016448e+03 2.388914e+01 5.273366e-02 1.949160e-01
# Plot with title “Scatterplot”

# %%
# e. Write a R function to plot histogram of some specific input attribute for any data set provided
new.function <- function(DEWP) {
   hist(DEWP)
}

new.function(DEWP)
# Out:
# Plot with title “Histogram of DEWP”

# %%
# c. Find coefficient of correlation using some R library function between above 2 attributes
cor(DEWP,TEMP, method = c("pearson", "kendall", "spearman"))
# Out:
# [1] 0.8246331

# %%
boxplot(DEWP,TEMP)
title("DEWP vs. TEMP")
# Out:
# Plot with title “DEWP vs. TEMP”
